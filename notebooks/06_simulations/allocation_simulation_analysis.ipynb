# %%
import sys
import os

# Get the parent directory (which contains offerallocationv2)
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add the parent directory to sys.path
sys.path.append(parent_dir)

# %%
# Databricks notebook source
from pyspark.sql import functions as F
from pyspark.sql.functions import col, weekofyear, to_date, expr, datediff
from pyspark.sql.window import Window
import customer_headroom.utils.persist_utils as persist_utils
from customer_headroom import config
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/yt/1z5jb1w10952dtlrg37sz5z80000gn/T/ipykernel_13522/354288453.py in ?()
#       1 # Databricks notebook source
# ----> 2 from pyspark.sql import functions as F
#       3 from pyspark.sql.functions import col, weekofyear, to_date, expr, datediff
#       4 from pyspark.sql.window import Window
#       5 import customer_headroom.utils.persist_utils as persist_utils
#
# ~/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Cases/MNS/databricks-env-10/lib/python3.10/site-packages/pyspark/__init__.py in ?()
#     144 # To avoid circular dependencies
#     145 from pyspark.context import SparkContext
#     146
#     147 # for back compatibility
# --> 148 from pyspark.sql import SQLContext, HiveContext, Row  # noqa: F401
#     149
#     150 __all__ = [
#     151     "SparkConf",
#
# ~/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Cases/MNS/databricks-env-10/lib/python3.10/site-packages/pyspark/sql/__init__.py in ?()
#      39     - :class:`pyspark.sql.Window`
#      40       For working with window functions.
#      41 """
#      42 from pyspark.sql.types import Row
# ---> 43 from pyspark.sql.context import SQLContext, HiveContext, UDFRegistration, UDTFRegistration
#      44 from pyspark.sql.session import SparkSession
#      45 from pyspark.sql.column import Column
#      46 from pyspark.sql.catalog import Catalog
#
# ~/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Cases/MNS/databricks-env-10/lib/python3.10/site-packages/pyspark/sql/context.py in ?()
#      35 from py4j.java_gateway import JavaObject
#      36
#      37 from pyspark import since, _NoValue
#      38 from pyspark._globals import _NoValueType
# ---> 39 from pyspark.sql.session import _monkey_patch_RDD, SparkSession
#      40 from pyspark.sql.dataframe import DataFrame
#      41 from pyspark.sql.readwriter import DataFrameReader
#      42 from pyspark.sql.streaming import DataStreamReader
#
# ~/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Cases/MNS/databricks-env-10/lib/python3.10/site-packages/pyspark/sql/session.py in ?()
#      44 from pyspark.rdd import RDD
#      45 from pyspark.sql.column import _to_java_column
#      46 from pyspark.sql.conf import RuntimeConfig
#      47 from pyspark.sql.dataframe import DataFrame
# ---> 48 from pyspark.sql.functions import lit
#      49 from pyspark.sql.pandas.conversion import SparkConversionMixin
#      50 from pyspark.sql.readwriter import DataFrameReader
#      51 from pyspark.sql.sql_formatter import SQLStringFormatter
#
# ~/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Cases/MNS/databricks-env-10/lib/python3.10/site-packages/pyspark/sql/functions/__init__.py in ?()
#      16 #
#      17
#      18 """PySpark Functions"""
#      19
# ---> 20 from pyspark.sql.functions.builtin import *  # noqa: F401,F403
#      21 from pyspark.sql.functions import partitioning  # noqa: F401,F403
#
# ~/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Cases/MNS/databricks-env-10/lib/python3.10/site-packages/pyspark/sql/functions/builtin.py in ?()
#      48 from pyspark.sql.types import ArrayType, DataType, StringType, StructType, _from_numpy_type
#      49
#      50 # Keep UserDefinedFunction import for backwards compatible import; moved in SPARK-22409
#      51 from pyspark.sql.udf import UserDefinedFunction, _create_py_udf  # noqa: F401
# ---> 52 from pyspark.sql.udtf import AnalyzeArgument, AnalyzeResult  # noqa: F401
#      53 from pyspark.sql.udtf import OrderingColumn, PartitioningColumn  # noqa: F401
#      54 from pyspark.sql.udtf import SkipRestOfInputTableException  # noqa: F401
#      55 from pyspark.sql.udtf import UserDefinedTableFunction, _create_py_udtf
#
# ImportError: cannot import name 'AnalyzeArgument' from 'pyspark.sql.udtf' (/Users/aidasanikeshkanima/Library/CloudStorage/OneDrive-TheBostonConsultingGroup,Inc/Documents/Cases/MNS/databricks-env-10/lib/python3.10/site-packages/pyspark/sql/udtf.py)

# %%
baseline_columns = ['baseline_85_stretch_0_perc', 'baseline_85_stretch_10_perc', 'baseline_85_stretch_30_perc']

# Retrieve the column that contains '0_stretch'
zero_stretch_columns = [col for col in baseline_columns if 'stretch_0_perc' in col]

# %%
zero_stretch_columns
# Out:
# ['baseline_85_stretch_0_perc']

# %%
from databricks.connect import DatabricksSession
spark = DatabricksSession.builder.getOrCreate()

# %%
trans_before_june_accu = persist_utils.read_table(
    table_name = config.factory_tbl_all_transaction_line_dev,
    where= "EVENT_DATE >= '2023-06-01'"
           and "EVENT_DATE <= '2024-05-31'"
           and "sparks_reg_date <= '2023-06-01'"
           and "trans_line_type = 'S'"
           and "division_id = 'FD'"
           and "sparks_account_id is not null")
